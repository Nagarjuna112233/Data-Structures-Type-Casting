# %% [markdown]
# # Import data/Load data

# %% [markdown]
# - option : path +(file name with extension)

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\NAGARJUNA'

# %%
cd C:\\Users\\NAGARJUNA
# Out:
# C:\Users\NAGARJUNA

# %%
df =pd.read_excel(r'tips.xlsx')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = pd.read_csv(r'tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
#first 5 observation
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#last 5 observation 
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
#dimensions of the data frame
df.shape
# Out:
# (244, 7)

# %%
#return on int representing the number of elements.
df.size
# Out:
# 1708

# %%
#column names/variable names
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#column names/variable
df.keys()
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
#to remove column names
df=df.rename (columns={'sex':"gender",'size':'no_of_members'})

# %%
df.dtypes
# Out:
# total_bill       float64
# tip              float64
# gender            object
# smoker            object
# day               object
# time              object
# no_of_members      int64
# dtype: object

# %% [markdown]
# **concise summary of a DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   total_bill     244 non-null    float64
#  1   tip            244 non-null    float64
#  2   gender         244 non-null    object
#  3   smoker         244 non-null    object
#  4   day            244 non-null    object
#  5   time           244 non-null    object
#  6   no_of_members  244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# **check for missing values**

# %%
df.isnull().sum()
# Out:
# total_bill       0
# tip              0
# gender           0
# smoker           0
# day              0
# time             0
# no_of_members    0
# dtype: int64

# %% [markdown]
# **to access the data of a single column**

# %%
df.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df['gender']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: gender, Length: 244, dtype: object

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
# 5       No
# 6       No
# 7       No
# 8       No
# 9       No
# 10      No
# 11      No
# 12      No
# 13      No
# 14      No
# 15      No
# 16      No
# 17      No
# 18      No
# 19      No
# 20      No
# 21      No
# 22      No
# 23      No
# 24      No
# 25      No
# 26      No
# 27      No
# 28      No
# 29      No
# 30      No
# 31      No
# 32      No
# 33      No
# 34      No
# 35      No
# 36      No
# 37      No
# 38      No
# 39      No
# 40      No
# 41      No
# 42      No
# 43      No
# 44      No
# 45      No
# 46      No
# 47      No
# 48      No
# 49      No
# 50      No
# 51      No
# 52      No
# 53      No
# 54      No
# 55      No
# 56     Yes
# 57      No
# 58     Yes
# 59      No
# 60     Yes
# 61     Yes
# 62     Yes
# 63     Yes
# 64      No
# 65      No
# 66      No
# 67     Yes
# 68      No
# 69     Yes
# 70      No
# 71      No
# 72     Yes
# 73     Yes
# 74      No
# 75      No
# ...

# %%
df['no_of_members']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
# 5      4
# 6      2
# 7      4
# 8      2
# 9      2
# 10     2
# 11     4
# 12     2
# 13     4
# 14     2
# 15     2
# 16     3
# 17     3
# 18     3
# 19     3
# 20     2
# 21     2
# 22     2
# 23     4
# 24     2
# 25     4
# 26     2
# 27     2
# 28     2
# 29     2
# 30     2
# 31     4
# 32     2
# 33     4
# 34     2
# 35     3
# 36     3
# 37     3
# 38     3
# 39     3
# 40     3
# 41     2
# 42     2
# 43     2
# 44     4
# 45     2
# 46     2
# 47     4
# 48     3
# 49     2
# 50     2
# 51     2
# 52     4
# 53     2
# 54     4
# 55     2
# 56     4
# 57     2
# 58     2
# 59     4
# 60     2
# 61     2
# 62     2
# 63     4
# 64     3
# 65     3
# 66     2
# 67     1
# 68     2
# 69     2
# 70     2
# 71     3
# 72     2
# 73     2
# 74     2
# 75     2
# 76     2
# 77     4
# 78     2
# 79     2
# 80     2
# 81     2
# 82     1
# 83     2
# 84     2
# 85     4
# 86     2
# 87     2
# 88     2
# 89     2
# ...

# %%
df['time']
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
# 5      Dinner
# 6      Dinner
# 7      Dinner
# 8      Dinner
# 9      Dinner
# 10     Dinner
# 11     Dinner
# 12     Dinner
# 13     Dinner
# 14     Dinner
# 15     Dinner
# 16     Dinner
# 17     Dinner
# 18     Dinner
# 19     Dinner
# 20     Dinner
# 21     Dinner
# 22     Dinner
# 23     Dinner
# 24     Dinner
# 25     Dinner
# 26     Dinner
# 27     Dinner
# 28     Dinner
# 29     Dinner
# 30     Dinner
# 31     Dinner
# 32     Dinner
# 33     Dinner
# 34     Dinner
# 35     Dinner
# 36     Dinner
# 37     Dinner
# 38     Dinner
# 39     Dinner
# 40     Dinner
# 41     Dinner
# 42     Dinner
# 43     Dinner
# 44     Dinner
# 45     Dinner
# 46     Dinner
# 47     Dinner
# 48     Dinner
# 49     Dinner
# 50     Dinner
# 51     Dinner
# 52     Dinner
# 53     Dinner
# 54     Dinner
# 55     Dinner
# 56     Dinner
# 57     Dinner
# 58     Dinner
# 59     Dinner
# 60     Dinner
# 61     Dinner
# ...

# %%
df.time
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
# 5      Dinner
# 6      Dinner
# 7      Dinner
# 8      Dinner
# 9      Dinner
# 10     Dinner
# 11     Dinner
# 12     Dinner
# 13     Dinner
# 14     Dinner
# 15     Dinner
# 16     Dinner
# 17     Dinner
# 18     Dinner
# 19     Dinner
# 20     Dinner
# 21     Dinner
# 22     Dinner
# 23     Dinner
# 24     Dinner
# 25     Dinner
# 26     Dinner
# 27     Dinner
# 28     Dinner
# 29     Dinner
# 30     Dinner
# 31     Dinner
# 32     Dinner
# 33     Dinner
# 34     Dinner
# 35     Dinner
# 36     Dinner
# 37     Dinner
# 38     Dinner
# 39     Dinner
# 40     Dinner
# 41     Dinner
# 42     Dinner
# 43     Dinner
# 44     Dinner
# 45     Dinner
# 46     Dinner
# 47     Dinner
# 48     Dinner
# 49     Dinner
# 50     Dinner
# 51     Dinner
# 52     Dinner
# 53     Dinner
# 54     Dinner
# 55     Dinner
# 56     Dinner
# 57     Dinner
# 58     Dinner
# 59     Dinner
# 60     Dinner
# 61     Dinner
# ...

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df[['total_bill']]
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# 5         25.29
# 6          8.77
# 7         26.88
# 8         15.04
# 9         14.78
# 10        10.27
# 11        35.26
# 12        15.42
# 13        18.43
# 14        14.83
# 15        21.58
# 16        10.33
# 17        16.29
# 18        16.97
# 19        20.65
# 20        17.92
# 21        20.29
# 22        15.77
# 23        39.42
# 24        19.82
# 25        17.81
# 26        13.37
# 27        12.69
# 28        21.70
# 29        19.65
# 30         9.55
# 31        18.35
# 32        15.06
# 33        20.69
# 34        17.78
# 35        24.06
# 36        16.31
# 37        16.93
# 38        18.69
# 39        31.27
# 40        16.04
# 41        17.46
# 42        13.94
# 43         9.68
# 44        30.40
# 45        18.29
# 46        22.23
# 47        32.40
# 48        28.55
# 49        18.04
# 50        12.54
# 51        10.29
# 52        34.81
# 53         9.94
# ...

# %% [markdown]
# ***Convert pandas.series to 1D array***

# %%
df[['time']]
# Out:
#        time
# 0    Dinner
# 1    Dinner
# 2    Dinner
# 3    Dinner
# 4    Dinner
# 5    Dinner
# 6    Dinner
# 7    Dinner
# 8    Dinner
# 9    Dinner
# 10   Dinner
# 11   Dinner
# 12   Dinner
# 13   Dinner
# 14   Dinner
# 15   Dinner
# 16   Dinner
# 17   Dinner
# 18   Dinner
# 19   Dinner
# 20   Dinner
# 21   Dinner
# 22   Dinner
# 23   Dinner
# 24   Dinner
# 25   Dinner
# 26   Dinner
# 27   Dinner
# 28   Dinner
# 29   Dinner
# 30   Dinner
# 31   Dinner
# 32   Dinner
# 33   Dinner
# 34   Dinner
# 35   Dinner
# 36   Dinner
# 37   Dinner
# 38   Dinner
# 39   Dinner
# 40   Dinner
# 41   Dinner
# 42   Dinner
# 43   Dinner
# 44   Dinner
# 45   Dinner
# 46   Dinner
# 47   Dinner
# 48   Dinner
# 49   Dinner
# 50   Dinner
# 51   Dinner
# 52   Dinner
# 53   Dinner
# 54   Dinner
# 55   Dinner
# 56   Dinner
# 57   Dinner
# 58   Dinner
# 59   Dinner
# 60   Dinner
# 61   Dinner
# 62   Dinner
# 63   Dinner
# 64   Dinner
# 65   Dinner
# 66   Dinner
# 67   Dinner
# 68   Dinner
# 69   Dinner
# ...

# %%
df[['no_of_members']]
# Out:
#      no_of_members
# 0                2
# 1                3
# 2                3
# 3                2
# 4                4
# 5                4
# 6                2
# 7                4
# 8                2
# 9                2
# 10               2
# 11               4
# 12               2
# 13               4
# 14               2
# 15               2
# 16               3
# 17               3
# 18               3
# 19               3
# 20               2
# 21               2
# 22               2
# 23               4
# 24               2
# 25               4
# 26               2
# 27               2
# 28               2
# 29               2
# 30               2
# 31               4
# 32               2
# 33               4
# 34               2
# 35               3
# 36               3
# 37               3
# 38               3
# 39               3
# 40               3
# 41               2
# 42               2
# 43               2
# 44               4
# 45               2
# ...

# %%
df.dtypes
# Out:
# total_bill       float64
# tip              float64
# gender            object
# smoker            object
# day               object
# time              object
# no_of_members      int64
# dtype: object

# %%
df['total_bill'].values
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 20.29, 13.81, 11.02,
#        18.29, 17.59, 20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07,
#        26.86, 25.28, 14.73, 10.51, 17.92, 27.2 , 22.76, 17.29, 19.44,
#        16.66, 10.07, 32.68, 15.98, 34.83, 13.03, 18.28, 24.71, 21.16,
#        28.97, 22.49,  5.75, 16.32, 22.75, 40.17, 27.28, 12.03, 21.01,
#        12.46, 11.35, 15.38, 44.3 , 22.42, 20.92, 15.36, 20.49, 25.21,
#        18.24, 14.31, 14.  ,  7.25, 38.07, 23.95, 25.71, 17.31, 29.93,
# ...

# %% [markdown]
# ***to access the data of a multiple columns***

# %%
df[['total_bill','gender','smoker']]
# Out:
#      total_bill  gender smoker
# 0         16.99  Female     No
# 1         10.34    Male     No
# 2         21.01    Male     No
# 3         23.68    Male     No
# 4         24.59  Female     No
# 5         25.29    Male     No
# 6          8.77    Male     No
# 7         26.88    Male     No
# 8         15.04    Male     No
# 9         14.78    Male     No
# 10        10.27    Male     No
# 11        35.26  Female     No
# 12        15.42    Male     No
# 13        18.43    Male     No
# 14        14.83  Female     No
# 15        21.58    Male     No
# 16        10.33  Female     No
# 17        16.29    Male     No
# 18        16.97  Female     No
# 19        20.65    Male     No
# 20        17.92    Male     No
# 21        20.29  Female     No
# 22        15.77  Female     No
# 23        39.42    Male     No
# 24        19.82    Male     No
# 25        17.81    Male     No
# 26        13.37    Male     No
# 27        12.69    Male     No
# 28        21.70    Male     No
# ...

# %%
df[['gender','smoker','total_bill']]
# Out:
#      gender smoker  total_bill
# 0    Female     No       16.99
# 1      Male     No       10.34
# 2      Male     No       21.01
# 3      Male     No       23.68
# 4    Female     No       24.59
# 5      Male     No       25.29
# 6      Male     No        8.77
# 7      Male     No       26.88
# 8      Male     No       15.04
# 9      Male     No       14.78
# 10     Male     No       10.27
# 11   Female     No       35.26
# 12     Male     No       15.42
# 13     Male     No       18.43
# 14   Female     No       14.83
# 15     Male     No       21.58
# 16   Female     No       10.33
# 17     Male     No       16.29
# 18   Female     No       16.97
# 19     Male     No       20.65
# 20     Male     No       17.92
# 21   Female     No       20.29
# 22   Female     No       15.77
# 23     Male     No       39.42
# 24     Male     No       19.82
# 25     Male     No       17.81
# 26     Male     No       13.37
# 27     Male     No       12.69
# 28     Male     No       21.70
# ...

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df[['gender','smoker','tip']]
# Out:
#      gender smoker    tip
# 0    Female     No   1.01
# 1      Male     No   1.66
# 2      Male     No   3.50
# 3      Male     No   3.31
# 4    Female     No   3.61
# 5      Male     No   4.71
# 6      Male     No   2.00
# 7      Male     No   3.12
# 8      Male     No   1.96
# 9      Male     No   3.23
# 10     Male     No   1.71
# 11   Female     No   5.00
# 12     Male     No   1.57
# 13     Male     No   3.00
# 14   Female     No   3.02
# 15     Male     No   3.92
# 16   Female     No   1.67
# 17     Male     No   3.71
# 18   Female     No   3.50
# 19     Male     No   3.35
# 20     Male     No   4.08
# 21   Female     No   2.75
# 22   Female     No   2.23
# 23     Male     No   7.58
# 24     Male     No   3.18
# 25     Male     No   2.34
# 26     Male     No   2.00
# 27     Male     No   2.00
# 28     Male     No   4.30
# 29   Female     No   3.00
# 30     Male     No   1.45
# 31     Male     No   2.50
# 32   Female     No   3.00
# 33   Female     No   2.45
# ...

# %%
df[['smoker','tip']]
# Out:
#     smoker    tip
# 0       No   1.01
# 1       No   1.66
# 2       No   3.50
# 3       No   3.31
# 4       No   3.61
# 5       No   4.71
# 6       No   2.00
# 7       No   3.12
# 8       No   1.96
# 9       No   3.23
# 10      No   1.71
# 11      No   5.00
# 12      No   1.57
# 13      No   3.00
# 14      No   3.02
# 15      No   3.92
# 16      No   1.67
# 17      No   3.71
# 18      No   3.50
# 19      No   3.35
# 20      No   4.08
# 21      No   2.75
# 22      No   2.23
# 23      No   7.58
# 24      No   3.18
# 25      No   2.34
# 26      No   2.00
# 27      No   2.00
# 28      No   4.30
# 29      No   3.00
# 30      No   1.45
# 31      No   2.50
# 32      No   3.00
# 33      No   2.45
# 34      No   3.27
# 35      No   3.60
# 36      No   2.00
# 37      No   3.07
# 38      No   2.31
# 39      No   5.00
# 40      No   2.24
# 41      No   2.54
# 42      No   3.06
# 43      No   1.32
# 44      No   5.60
# 45      No   3.00
# 46      No   5.00
# 47      No   6.00
# 48      No   2.05
# ...

# %% [markdown]
# **Selecting Databy using iloc()**

# %% [markdown]
# - Works on the row index number & column index number

# %%
df.iloc[0,2]
# Out:
# 'Female'

# %%
df.iloc[0:5,2]
# Out:
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# Name: gender, dtype: object

# %%
df.iloc[4:220:15,2]
# Out:
# 4      Female
# 19       Male
# 34       Male
# 49       Male
# 64       Male
# 79       Male
# 94     Female
# 109    Female
# 124    Female
# 139    Female
# 154      Male
# 169    Female
# 184      Male
# 199      Male
# 214    Female
# Name: gender, dtype: object

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df.iloc[[4,10,16,22],[5,3]]
# Out:
#       time smoker
# 4   Dinner     No
# 10  Dinner     No
# 16  Dinner     No
# 22  Dinner     No

# %%
df.iloc[[23,34,45,45,5,43,4,6,],[2,1,4,3]]
# Out:
#     gender   tip  day smoker
# 23    Male  7.58  Sat     No
# 34    Male  3.27  Sat     No
# 45    Male  3.00  Sun     No
# 45    Male  3.00  Sun     No
# 5     Male  4.71  Sun     No
# 43    Male  1.32  Sun     No
# 4   Female  3.61  Sun     No
# 6     Male  2.00  Sun     No

# %%
df.iloc[[4,10,16,22],[2,3]]
# Out:
#     gender smoker
# 4   Female     No
# 10    Male     No
# 16  Female     No
# 22  Female     No

# %%
df.iloc[:,5]
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
# 5      Dinner
# 6      Dinner
# 7      Dinner
# 8      Dinner
# 9      Dinner
# 10     Dinner
# 11     Dinner
# 12     Dinner
# 13     Dinner
# 14     Dinner
# 15     Dinner
# 16     Dinner
# 17     Dinner
# 18     Dinner
# 19     Dinner
# 20     Dinner
# 21     Dinner
# 22     Dinner
# 23     Dinner
# 24     Dinner
# 25     Dinner
# 26     Dinner
# 27     Dinner
# 28     Dinner
# 29     Dinner
# 30     Dinner
# 31     Dinner
# 32     Dinner
# 33     Dinner
# 34     Dinner
# 35     Dinner
# 36     Dinner
# 37     Dinner
# 38     Dinner
# 39     Dinner
# 40     Dinner
# 41     Dinner
# 42     Dinner
# 43     Dinner
# 44     Dinner
# 45     Dinner
# 46     Dinner
# 47     Dinner
# 48     Dinner
# 49     Dinner
# 50     Dinner
# 51     Dinner
# 52     Dinner
# 53     Dinner
# 54     Dinner
# 55     Dinner
# 56     Dinner
# 57     Dinner
# 58     Dinner
# 59     Dinner
# 60     Dinner
# 61     Dinner
# ...

# %%
df.iloc[:,2]
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9        Male
# 10       Male
# 11     Female
# 12       Male
# 13       Male
# 14     Female
# 15       Male
# 16     Female
# 17       Male
# 18     Female
# 19       Male
# 20       Male
# 21     Female
# 22     Female
# 23       Male
# 24       Male
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29     Female
# 30       Male
# 31       Male
# 32     Female
# 33     Female
# 34       Male
# 35       Male
# 36       Male
# 37     Female
# 38       Male
# 39       Male
# 40       Male
# 41       Male
# 42       Male
# 43       Male
# 44       Male
# 45       Male
# 46       Male
# 47       Male
# 48       Male
# 49       Male
# 50       Male
# 51     Female
# 52     Female
# 53       Male
# 54       Male
# 55       Male
# 56       Male
# 57     Female
# 58       Male
# 59       Male
# 60       Male
# 61       Male
# ...

# %%
df.iloc[:,[2,3]]
# Out:
#      gender smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# 5      Male     No
# 6      Male     No
# 7      Male     No
# 8      Male     No
# 9      Male     No
# 10     Male     No
# 11   Female     No
# 12     Male     No
# 13     Male     No
# 14   Female     No
# 15     Male     No
# 16   Female     No
# 17     Male     No
# 18   Female     No
# 19     Male     No
# 20     Male     No
# 21   Female     No
# 22   Female     No
# 23     Male     No
# 24     Male     No
# 25     Male     No
# 26     Male     No
# 27     Male     No
# 28     Male     No
# 29   Female     No
# 30     Male     No
# 31     Male     No
# 32   Female     No
# 33   Female     No
# 34     Male     No
# 35     Male     No
# 36     Male     No
# 37   Female     No
# 38     Male     No
# 39     Male     No
# 40     Male     No
# 41     Male     No
# 42     Male     No
# 43     Male     No
# 44     Male     No
# 45     Male     No
# ...

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df.iloc[:,[2,0,6]]
# Out:
#      gender  total_bill  no_of_members
# 0    Female       16.99              2
# 1      Male       10.34              3
# 2      Male       21.01              3
# 3      Male       23.68              2
# 4    Female       24.59              4
# 5      Male       25.29              4
# 6      Male        8.77              2
# 7      Male       26.88              4
# 8      Male       15.04              2
# 9      Male       14.78              2
# 10     Male       10.27              2
# 11   Female       35.26              4
# 12     Male       15.42              2
# 13     Male       18.43              4
# 14   Female       14.83              2
# 15     Male       21.58              2
# 16   Female       10.33              3
# 17     Male       16.29              3
# 18   Female       16.97              3
# 19     Male       20.65              3
# 20     Male       17.92              2
# 21   Female       20.29              2
# 22   Female       15.77              2
# ...

# %% [markdown]
# **by using loc()**
# - Locate Named Indexes (Use the named index in the loc atribute)

# %%
df.loc[[4,10,16,22],["gender",'smoker']]
# Out:
#     gender smoker
# 4   Female     No
# 10    Male     No
# 16  Female     No
# 22  Female     No

# %%
df.loc[[4,10,16,22,45,4,45,65,76,87,43],["tip",'total_bill']]
# Out:
#      tip  total_bill
# 4   3.61       24.59
# 10  1.71       10.27
# 16  1.67       10.33
# 22  2.23       15.77
# 45  3.00       18.29
# 4   3.61       24.59
# 45  3.00       18.29
# 65  3.15       20.08
# 76  3.08       17.92
# 87  4.00       18.28
# 43  1.32        9.68

# %%
df.loc[[45,65,89,87,32,123,221],['total_bill',"gender",'time','tip','smoker','day']]
# Out:
#      total_bill  gender    time   tip smoker   day
# 45        18.29    Male  Dinner  3.00     No   Sun
# 65        20.08    Male  Dinner  3.15     No   Sat
# 89        21.16    Male   Lunch  3.00     No  Thur
# 87        18.28    Male   Lunch  4.00     No  Thur
# 32        15.06  Female  Dinner  3.00     No   Sat
# 123       15.95    Male   Lunch  2.00     No  Thur
# 221       13.42  Female   Lunch  3.48    Yes   Fri

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df.loc[4:223:20,["gender",'tip','day','time']]
# Out:
#      gender   tip   day    time
# 4    Female  3.61   Sun  Dinner
# 24     Male  3.18   Sat  Dinner
# 44     Male  5.60   Sun  Dinner
# 64     Male  2.64   Sat  Dinner
# 84     Male  2.03  Thur   Lunch
# 104  Female  4.08   Sat  Dinner
# 124  Female  2.52  Thur   Lunch
# 144  Female  2.30  Thur   Lunch
# 164  Female  3.00   Sun  Dinner
# 184    Male  3.00   Sun  Dinner
# 204    Male  4.00  Thur   Lunch

# %%
df.loc[:,'tip']
# Out:
# 0       1.01
# 1       1.66
# 2       3.50
# 3       3.31
# 4       3.61
# 5       4.71
# 6       2.00
# 7       3.12
# 8       1.96
# 9       3.23
# 10      1.71
# 11      5.00
# 12      1.57
# 13      3.00
# 14      3.02
# 15      3.92
# 16      1.67
# 17      3.71
# 18      3.50
# 19      3.35
# 20      4.08
# 21      2.75
# 22      2.23
# 23      7.58
# 24      3.18
# 25      2.34
# 26      2.00
# 27      2.00
# 28      4.30
# 29      3.00
# 30      1.45
# 31      2.50
# 32      3.00
# 33      2.45
# 34      3.27
# 35      3.60
# 36      2.00
# 37      3.07
# 38      2.31
# 39      5.00
# 40      2.24
# 41      2.54
# 42      3.06
# 43      1.32
# 44      5.60
# 45      3.00
# 46      5.00
# 47      6.00
# 48      2.05
# 49      3.00
# 50      2.50
# 51      2.60
# 52      5.20
# 53      1.56
# 54      4.34
# 55      3.51
# 56      3.00
# 57      1.50
# 58      1.76
# 59      6.73
# 60      3.21
# 61      2.00
# 62      1.98
# 63      3.76
# 64      2.64
# 65      3.15
# ...

# %%
df.loc[:,["gender","tip",'day']]
# Out:
#      gender    tip   day
# 0    Female   1.01   Sun
# 1      Male   1.66   Sun
# 2      Male   3.50   Sun
# 3      Male   3.31   Sun
# 4    Female   3.61   Sun
# 5      Male   4.71   Sun
# 6      Male   2.00   Sun
# 7      Male   3.12   Sun
# 8      Male   1.96   Sun
# 9      Male   3.23   Sun
# 10     Male   1.71   Sun
# 11   Female   5.00   Sun
# 12     Male   1.57   Sun
# 13     Male   3.00   Sun
# 14   Female   3.02   Sun
# 15     Male   3.92   Sun
# 16   Female   1.67   Sun
# 17     Male   3.71   Sun
# 18   Female   3.50   Sun
# 19     Male   3.35   Sat
# 20     Male   4.08   Sat
# 21   Female   2.75   Sat
# 22   Female   2.23   Sat
# 23     Male   7.58   Sat
# 24     Male   3.18   Sat
# 25     Male   2.34   Sat
# 26     Male   2.00   Sat
# 27     Male   2.00   Sat
# 28     Male   4.30   Sat
# 29   Female   3.00   Sat
# 30     Male   1.45   Sat
# 31     Male   2.50   Sat
# 32   Female   3.00   Sat
# 33   Female   2.45   Sat
# 34     Male   3.27   Sat
# 35     Male   3.60   Sat
# ...

# %% [markdown]
# # Filtering

# %% [markdown]
# - Selecting/extracting the data based on condition(s)
#
#
# **using 1 condition**

# %%
df[df["gender"]=="Male"]
# Out:
#      total_bill   tip gender smoker  day    time  no_of_members
# 1         10.34  1.66   Male     No  Sun  Dinner              3
# 2         21.01  3.50   Male     No  Sun  Dinner              3
# 3         23.68  3.31   Male     No  Sun  Dinner              2
# 5         25.29  4.71   Male     No  Sun  Dinner              4
# 6          8.77  2.00   Male     No  Sun  Dinner              2
# ..          ...   ...    ...    ...  ...     ...            ...
# 236       12.60  1.00   Male    Yes  Sat  Dinner              2
# 237       32.83  1.17   Male    Yes  Sat  Dinner              2
# 239       29.03  5.92   Male     No  Sat  Dinner              3
# 241       22.67  2.00   Male    Yes  Sat  Dinner              2
# 242       17.82  1.75   Male     No  Sat  Dinner              2
#
# [157 rows x 7 columns]

# %%
df[(df['tip']>=6)]
# Out:
#      total_bill    tip  gender smoker   day    time  no_of_members
# 23        39.42   7.58    Male     No   Sat  Dinner              4
# 47        32.40   6.00    Male     No   Sun  Dinner              4
# 59        48.27   6.73    Male     No   Sat  Dinner              4
# 141       34.30   6.70    Male     No  Thur   Lunch              6
# 170       50.81  10.00    Male    Yes   Sat  Dinner              3
# 183       23.17   6.50    Male    Yes   Sun  Dinner              4
# 212       48.33   9.00    Male     No   Sat  Dinner              4
# 214       28.17   6.50  Female    Yes   Sat  Dinner              3

# %%
df[(df['no_of_members']>=6)]
# Out:
#      total_bill  tip  gender smoker   day    time  no_of_members
# 125       29.80  4.2  Female     No  Thur   Lunch              6
# 141       34.30  6.7    Male     No  Thur   Lunch              6
# 143       27.05  5.0  Female     No  Thur   Lunch              6
# 156       48.17  5.0    Male     No   Sun  Dinner              6

# %%
df[(df['time']>='Lunch')]
# Out:
#      total_bill   tip  gender smoker   day   time  no_of_members
# 77        27.20  4.00    Male     No  Thur  Lunch              4
# 78        22.76  3.00    Male     No  Thur  Lunch              2
# 79        17.29  2.71    Male     No  Thur  Lunch              2
# 80        19.44  3.00    Male    Yes  Thur  Lunch              2
# 81        16.66  3.40    Male     No  Thur  Lunch              2
# 82        10.07  1.83  Female     No  Thur  Lunch              1
# 83        32.68  5.00    Male    Yes  Thur  Lunch              2
# 84        15.98  2.03    Male     No  Thur  Lunch              2
# 85        34.83  5.17  Female     No  Thur  Lunch              4
# 86        13.03  2.00    Male     No  Thur  Lunch              2
# 87        18.28  4.00    Male     No  Thur  Lunch              2
# 88        24.71  5.85    Male     No  Thur  Lunch              2
# 89        21.16  3.00    Male     No  Thur  Lunch              2
# ...

# %%
df[(df['total_bill']>=40)]
# Out:
#      total_bill    tip  gender smoker   day    time  no_of_members
# 59        48.27   6.73    Male     No   Sat  Dinner              4
# 95        40.17   4.73    Male    Yes   Fri  Dinner              4
# 102       44.30   2.50  Female    Yes   Sat  Dinner              3
# 142       41.19   5.00    Male     No  Thur   Lunch              5
# 156       48.17   5.00    Male     No   Sun  Dinner              6
# 170       50.81  10.00    Male    Yes   Sat  Dinner              3
# 182       45.35   3.50    Male    Yes   Sun  Dinner              3
# 184       40.55   3.00    Male    Yes   Sun  Dinner              2
# 197       43.11   5.00  Female    Yes  Thur   Lunch              4
# 212       48.33   9.00    Male     No   Sat  Dinner              4

# %%
df[(df['tip']<6)]
# Out:
#      total_bill   tip  gender smoker   day    time  no_of_members
# 0         16.99  1.01  Female     No   Sun  Dinner              2
# 1         10.34  1.66    Male     No   Sun  Dinner              3
# 2         21.01  3.50    Male     No   Sun  Dinner              3
# 3         23.68  3.31    Male     No   Sun  Dinner              2
# 4         24.59  3.61  Female     No   Sun  Dinner              4
# 5         25.29  4.71    Male     No   Sun  Dinner              4
# 6          8.77  2.00    Male     No   Sun  Dinner              2
# 7         26.88  3.12    Male     No   Sun  Dinner              4
# 8         15.04  1.96    Male     No   Sun  Dinner              2
# 9         14.78  3.23    Male     No   Sun  Dinner              2
# 10        10.27  1.71    Male     No   Sun  Dinner              2
# 11        35.26  5.00  Female     No   Sun  Dinner              4
# 12        15.42  1.57    Male     No   Sun  Dinner              2
# ...

# %%
df[(df['smoker']>='Yes')]
# Out:
#      total_bill    tip  gender smoker   day    time  no_of_members
# 56        38.01   3.00    Male    Yes   Sat  Dinner              4
# 58        11.24   1.76    Male    Yes   Sat  Dinner              2
# 60        20.29   3.21    Male    Yes   Sat  Dinner              2
# 61        13.81   2.00    Male    Yes   Sat  Dinner              2
# 62        11.02   1.98    Male    Yes   Sat  Dinner              2
# 63        18.29   3.76    Male    Yes   Sat  Dinner              4
# 67         3.07   1.00  Female    Yes   Sat  Dinner              1
# 69        15.01   2.09    Male    Yes   Sat  Dinner              2
# 72        26.86   3.14  Female    Yes   Sat  Dinner              2
# 73        25.28   5.00  Female    Yes   Sat  Dinner              2
# 76        17.92   3.08    Male    Yes   Sat  Dinner              2
# 80        19.44   3.00    Male    Yes  Thur   Lunch              2
# 83        32.68   5.00    Male    Yes  Thur   Lunch              2
# ...

# %% [markdown]
# **using multiple conditions**
# - Syntax : df[(condition1) or/and (condtion2)]

# %%
df[(df['tip']>=7 & (df["gender"]=="Male"))]
# Out:
#      total_bill    tip  gender smoker   day    time  no_of_members
# 0         16.99   1.01  Female     No   Sun  Dinner              2
# 1         10.34   1.66    Male     No   Sun  Dinner              3
# 2         21.01   3.50    Male     No   Sun  Dinner              3
# 3         23.68   3.31    Male     No   Sun  Dinner              2
# 4         24.59   3.61  Female     No   Sun  Dinner              4
# 5         25.29   4.71    Male     No   Sun  Dinner              4
# 6          8.77   2.00    Male     No   Sun  Dinner              2
# 7         26.88   3.12    Male     No   Sun  Dinner              4
# 8         15.04   1.96    Male     No   Sun  Dinner              2
# 9         14.78   3.23    Male     No   Sun  Dinner              2
# 10        10.27   1.71    Male     No   Sun  Dinner              2
# 11        35.26   5.00  Female     No   Sun  Dinner              4
# 12        15.42   1.57    Male     No   Sun  Dinner              2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   total_bill     244 non-null    float64
#  1   tip            244 non-null    float64
#  2   gender         244 non-null    object
#  3   smoker         244 non-null    object
#  4   day            244 non-null    object
#  5   time           244 non-null    object
#  6   no_of_members  244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df[(df['tip']>=3) | (df['gender']=='Female')]
# Out:
#      total_bill   tip  gender smoker   day    time  no_of_members
# 0         16.99  1.01  Female     No   Sun  Dinner              2
# 2         21.01  3.50    Male     No   Sun  Dinner              3
# 3         23.68  3.31    Male     No   Sun  Dinner              2
# 4         24.59  3.61  Female     No   Sun  Dinner              4
# 5         25.29  4.71    Male     No   Sun  Dinner              4
# ..          ...   ...     ...    ...   ...     ...            ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner              2
# 238       35.83  4.67  Female     No   Sat  Dinner              3
# 239       29.03  5.92    Male     No   Sat  Dinner              3
# 240       27.18  2.00  Female    Yes   Sat  Dinner              2
# 243       18.78  3.00  Female     No  Thur  Dinner              2
#
# [169 rows x 7 columns]

# %%
df[(df['gender']=='Female') | (df['tip']>=3) & (df['total_bill']<=60)]
# Out:
#      total_bill   tip  gender smoker   day    time  no_of_members
# 0         16.99  1.01  Female     No   Sun  Dinner              2
# 2         21.01  3.50    Male     No   Sun  Dinner              3
# 3         23.68  3.31    Male     No   Sun  Dinner              2
# 4         24.59  3.61  Female     No   Sun  Dinner              4
# 5         25.29  4.71    Male     No   Sun  Dinner              4
# ..          ...   ...     ...    ...   ...     ...            ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner              2
# 238       35.83  4.67  Female     No   Sat  Dinner              3
# 239       29.03  5.92    Male     No   Sat  Dinner              3
# 240       27.18  2.00  Female    Yes   Sat  Dinner              2
# 243       18.78  3.00  Female     No  Thur  Dinner              2
#
# [169 rows x 7 columns]

# %%
df[(df['gender']=='Female')  & (df['total_bill']>=25)]
# Out:
#      total_bill   tip  gender smoker   day    time  no_of_members
# 11        35.26  5.00  Female     No   Sun  Dinner              4
# 52        34.81  5.20  Female     No   Sun  Dinner              4
# 57        26.41  1.50  Female     No   Sat  Dinner              2
# 72        26.86  3.14  Female    Yes   Sat  Dinner              2
# 73        25.28  5.00  Female    Yes   Sat  Dinner              2
# 85        34.83  5.17  Female     No  Thur   Lunch              4
# 102       44.30  2.50  Female    Yes   Sat  Dinner              3
# 114       25.71  4.00  Female     No   Sun  Dinner              3
# 125       29.80  4.20  Female     No  Thur   Lunch              6
# 143       27.05  5.00  Female     No  Thur   Lunch              6
# 155       29.85  5.14  Female     No   Sun  Dinner              5
# 157       25.00  3.75  Female     No   Sun  Dinner              4
# 197       43.11  5.00  Female    Yes  Thur   Lunch              4
# ...

# %% [markdown]
# **to unique values**

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['gender'].value_counts()/len(df)
# Out:
# gender
# Male      0.643443
# Female    0.356557
# Name: count, dtype: float64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Male      0.643443
# Female    0.356557
# Name: proportion, dtype: float64

# %% [markdown]
# # crosstab

# %% [markdown]
# - applied on 2 discreate variables

# %%
pd.crosstab(df['gender'],df['smoker'])
# Out:
# smoker  No  Yes
# gender
# Female  54   33
# Male    97   60

# %%
pd.crosstab(df['gender'],df['smoker'],margins=True)
# Out:
# smoker   No  Yes  All
# gender
# Female   54   33   87
# Male     97   60  157
# All     151   93  244

# %% [markdown]
# # Groupby

# %%
#Grouping on basis of "Gender" and using sum () function for "TB".
df.groupby('gender')["tip"].mean()
# Out:
# gender
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %%
df.groupby('total_bill')['tip'].mean()
# Out:
# total_bill
# 3.07      1.000
# 5.75      1.000
# 7.25      3.075
# 7.51      2.000
# 7.56      1.440
#           ...
# 45.35     3.500
# 48.17     5.000
# 48.27     6.730
# 48.33     9.000
# 50.81    10.000
# Name: tip, Length: 229, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   total_bill     244 non-null    float64
#  1   tip            244 non-null    float64
#  2   gender         244 non-null    object
#  3   smoker         244 non-null    object
#  4   day            244 non-null    object
#  5   time           244 non-null    object
#  6   no_of_members  244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.groupby('gender')['total_bill'].mean()
# Out:
# (gender
#  Female    18.056897
#  Male      20.744076
#  Name: total_bill, dtype: float64,)

# %%
df.groupby('no_of_members')['tip'].mean()
# Out:
# no_of_members
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64
