# %% [markdown]
# # Data Analytics Project
# - Understand the Business Problem(project)
# - Data Understanding
# - Data Cleaning
# - Analysis
# - Presentation

# %% [markdown]
# # Step-1 : Business Problem
#
# - Retaurant owner wants detailed report on sales
#
# - Whatever the data i have provided, from that do analysis & submit you report/inferences

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Step-2: Load the data

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Step-2.2 : Data Understanding
#
# - We understanding the each & every column name very clearly (do research)
#
# - understanding the dataset by applying info(),shapes,dtypes,columns
#
# - list the continous, discrete categorical,discrete count
#
# - Observe the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df['sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time']
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: object

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
continous = ['total_bill','tip']

discrete_categorical = ['sex','smoker','time']

discrete_count = ['size']

# %% [markdown]
# # Descriptive Sattistics

# %%
df[continous].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df[discrete_categorical].describe()
# Out:
#          sex smoker    time
# count    244    244     244
# unique     2      2       2
# top     Male     No  Dinner
# freq     157    151     176

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Plots for continous Data
#
# 1. Univariable (single Variable)
#
#      - Histogram
#      - Boxplot
#
# 2. Bivariate (Plot between two Variables)
#
#      - Scatter plot
#      - Line plot
#      - Joint plot
#      - Violin plot
#
# 3. Multivariate (More than 2Variables)
#
#      - Pair plot
#      - Heatmap

# %% [markdown]
# # Histogram/Distribution plot

# %%
sns.histplot(df['total_bill'],bins=10,kde=True)
plt.show()

# %%
sns.kdeplot(df['total_bill'])
plt.show()

# %% [markdown]
# # Box plot

# %%
sns.boxplot(df['tip'])
plt.show()

# %%
sns.boxplot(x=df['tip'])
plt.show()

# %%
sns.boxplot(df['total_bill'])
plt.show()

# %%
sns.boxplot(y=df['total_bill'])
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'])
plt.show()

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'],hue=df['sex'])
plt.show()

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],hue=df['sex'])
plt.show()

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],col=df['size'],col_wrap=2,hue=df['sex'])
plt.show()

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],col=df['size'],col_wrap=3,hue=df['sex'])
plt.show()

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],col=df['size'],col_wrap=5,hue=df['sex'])
plt.show()

# %% [markdown]
# # Line Plot

# %%
df['s.no'] = pd.DataFrame(np.arange(1,245))
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  s.no
# 0         16.99  1.01  Female     No   Sun  Dinner     2     1
# 1         10.34  1.66    Male     No   Sun  Dinner     3     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2     4
# 4         24.59  3.61  Female     No   Sun  Dinner     4     5
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   240
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   241
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   242
# 242       17.82  1.75    Male     No   Sat  Dinner     2   243
# 243       18.78  3.00  Female     No  Thur  Dinner     2   244
#
# [244 rows x 8 columns]

# %%
sns.relplot(x ='s.no',y ='tip',data =df,kind="line")
plt.show()

# %%
df.drop('s.no',axis=1,inplace=True)

# %% [markdown]
# # Joint Plot
#
# A join plot allows to study the relationship between 2 numeric varaiables. The central chart display their correlation.it is usually a scatterplot, a hexbin plot, a 2D histogram or a 2d density plot.

# %%
sns.jointplot(x ='total_bill',y = 'tip' ,data = df)
plt.show()

# %% [markdown]
# # Violon Plot
#
# Violin plot helps us to see both the distribution of data in terms of kernel density estimation and the box plot

# %%
sns.violinplot(x ='total_bill',y = 'sex',data=df)
plt.show()

# %% [markdown]
# # Pair Plot-Multiple continous variables
#
# A "Pairs Plot" is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value.like this: pairs plots are just elaborations on this, showing all variables paired with all the other variables

# %%
sns.pairplot(df,vars=continous)
plt.show()

# %% [markdown]
# # Heat Map
# A heatmap uses colored cells to represent relation between variables
#
# # Heatmap (for correlation)
# - A correlation heatmap uses colored cells to show a 2D correlation matrix(table) between two numeric dimensions.
#
# - It is very important in Features Selection

# %% [markdown]
# add siple![image.png](attachment:357536a3-535d-4c95-908f-c9b4e95e08bf.png)

# %%
c_m = df[continous].corr()
c_m
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.heatmap(c_m,annot=True)
plt.show()

# %% [markdown]
# # Plots for Discrete Data
#
# 1. Univariate (Single Variable)
#
#     - Pie Plot
#     - Bar Plot
#     - Count Plot
#
# 2. Bivariate (Plot between two Variables)
#     - Boxplot---> one discrete variable & one continous variable

# %% [markdown]
# # Count Plot

# %%
df['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.countplot(x='smoker',data=df)
plt.show()

# %%
sns.countplot(y='smoker',data=df)
plt.show()

# %% [markdown]
# # Bar Plot

# %%
df.groupby('sex')['total_bill'].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
sns.catplot(x='sex',y='total_bill',data=df,kind='bar')
plt.show()

# %% [markdown]
# - it is a bivareate variable plot
# - In a bar plot we take 1 continous variable in (y-axis) and 1 discrete variable in (x-axis).
# - then we consider as a bivariate plot
# - in the above fig that black line indicates a bar within a multiplebars

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar',hue='day')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar',hue='size')
plt.show()

# %%
df[(df['day']=='Sat') & (df['size']==5)]
# Out:
#      total_bill  tip   sex smoker  day    time  size
# 216       28.15  3.0  Male    Yes  Sat  Dinner     5

# %%
df[(df['day']=='Sat') & (df['size']==4)]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# 25        17.81  2.34    Male     No  Sat  Dinner     4
# 31        18.35  2.50    Male     No  Sat  Dinner     4
# 33        20.69  2.45  Female     No  Sat  Dinner     4
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 59        48.27  6.73    Male     No  Sat  Dinner     4
# 63        18.29  3.76    Male    Yes  Sat  Dinner     4
# 207       38.73  3.00    Male    Yes  Sat  Dinner     4
# 211       25.89  5.16    Male    Yes  Sat  Dinner     4
# 212       48.33  9.00    Male     No  Sat  Dinner     4
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4
# 227       20.45  3.00    Male     No  Sat  Dinner     4
# 230       24.01  2.00    Male    Yes  Sat  Dinner     4

# %%
df[(df['day']=='Sat') & (df['size']==3)]
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 19        20.65   3.35    Male     No  Sat  Dinner     3
# 35        24.06   3.60    Male     No  Sat  Dinner     3
# 36        16.31   2.00    Male     No  Sat  Dinner     3
# 37        16.93   3.07  Female     No  Sat  Dinner     3
# 38        18.69   2.31    Male     No  Sat  Dinner     3
# 39        31.27   5.00    Male     No  Sat  Dinner     3
# 40        16.04   2.24    Male     No  Sat  Dinner     3
# 64        17.59   2.64    Male     No  Sat  Dinner     3
# 65        20.08   3.15    Male     No  Sat  Dinner     3
# 71        17.07   3.00  Female     No  Sat  Dinner     3
# 102       44.30   2.50  Female    Yes  Sat  Dinner     3
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 206       26.59   3.41    Male    Yes  Sat  Dinner     3
# 210       30.06   2.00    Male    Yes  Sat  Dinner     3
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3
# ...

# %%
df[(df['day']=='Sat') & (df['size']==2)]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 24        19.82  3.18    Male     No  Sat  Dinner     2
# 26        13.37  2.00    Male     No  Sat  Dinner     2
# 27        12.69  2.00    Male     No  Sat  Dinner     2
# 28        21.70  4.30    Male     No  Sat  Dinner     2
# 29        19.65  3.00  Female     No  Sat  Dinner     2
# 30         9.55  1.45    Male     No  Sat  Dinner     2
# 32        15.06  3.00  Female     No  Sat  Dinner     2
# 34        17.78  3.27    Male     No  Sat  Dinner     2
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ...

# %%
df[(df['day']=='Sat') & (df['size']==1)]
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1
# 111        7.25  1.0  Female     No  Sat  Dinner     1

# %%
sns.catplot(x='time',y='total_bill',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='time',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='time',y='total_bill',data=df,kind='bar',hue='day')
plt.show()

# %%
df[(df['time']=='Dinner') & (df['size']==2)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [104 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
sns.catplot(x='smoker',y='total_bill',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,kind='bar',hue='day')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,hue='size',kind='bar')
plt.show()

# %% [markdown]
# - It is a multivariate variable plot
#
# - In a bar plot we take 1 continous variable (y-axis) and 2 discrete variable (x-axis) and (hue='discrete column').
#
# - Then we consider as a multivariate plot
#
# - In the above fig that black line indicates a bar within a multiple bars
#
# - The "hue" means we can write only discrete variable.
#
# - If no black lines means only one record

# %% [markdown]
# # Box Plot
#
# - In a box plot we take 1 continous variable (y-axis) and 2 discrete variable (x-axis) and (hue=).

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='box')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='box',hue='time')
plt.show()

# %% [markdown]
# - In this box plot we can observe the minimun ,maximum and mean.
#
# - It is a bivariate variable plot
#
# - In a bar plot we take 1 continous variable (y-axis) and 2 discrete variable (x-axis) and (hue='discrete column').
#
# - Then we consider as a bivaiate plot
#
# - In the above fig that black line indicates a bar within a multiple bars
#
# - The "hue" means we can write only discrete variable.

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='box',hue='size')
plt.show()

# %%
sns.catplot(x='sex',y='total_bill',data=df,kind='box')
plt.show()

# %%
sns.catplot(x='sex',y='total_bill',data=df)
plt.show()

# %%
sns.catplot(x='sex',y='total_bill',data=df,kind='box',hue='size')
plt.show()

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# # Questions
#
# - Average bill for day wise
# - Which time,i have more transcations
# - which time, maxbill amount
# - which time, total_sales are high

# %%
df.groupby('day')['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %%
df.groupby('time')['total_bill'].mean()
# Out:
# time
# Dinner    20.797159
# Lunch     17.168676
# Name: total_bill, dtype: float64

# %%
df.groupby('time')['total_bill'].sum()
# Out:
# time
# Dinner    3660.30
# Lunch     1167.47
# Name: total_bill, dtype: float64

# %%
pd.crosstab(df['time'],df['sex'],margins=True)
# Out:
# sex     Female  Male  All
# time
# Dinner      52   124  176
# Lunch       35    33   68
# All         87   157  244

# %%
pd.crosstab(df['day'],df['time'],margins=True)
# Out:
# time  Dinner  Lunch  All
# day
# Fri       12      7   19
# Sat       87      0   87
# Sun       76      0   76
# Thur       1     61   62
# All      176     68  244
